# %%
from dotenv import load_dotenv
from openai import OpenAI
import os
# Out:
# True

# %%
load_dotenv(".env")

gemini_key = os.getenv("GEMINI_API_KEY")
if gemini_key is None:
    raise KeyError("GEMINI_API_KEY not found in .env")


client = OpenAI(api_key=gemini_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
response = client.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=[
        {   "role": "system",
            "content": "You are a helpful assistant."
        },
        {
            "role": "user",
            "content": "Explain to me how AI works"
        }
    ]
)
print(response.choices[0].message.content)
# Out:
# The field of Artificial Intelligence (AI) is vast and constantly evolving, but at its core, AI aims to create systems that can perform tasks that typically require human intelligence. Think of things like learning, problem-solving, decision-making, understanding language, and recognizing patterns.
#
# Instead of giving a computer a rigid, step-by-step set of instructions for every single possible scenario (which is traditional programming), AI systems learn and adapt. Here's a breakdown of the key concepts:
#
# **1. Data is King (and Queen!)**
#
# *   **Training Data:** AI, especially the most popular forms like machine learning, learns from massive amounts of data. This data can be anything: text, images, sounds, numbers, videos, etc. The quality and quantity of this data are crucial for an AI's performance.
# *   **Examples:** To teach an AI to recognize cats, you'd show it thousands, even millions, of images labeled "cat." To teach it to translate languages, you'd feed it vast amounts of parallel text in different languages.
#
# **2. Algorithms: The "Brain" of the AI**
#
# *   **Machine Learning (ML):** This is the most common approach to AI today. Instead of being explicitly programmed, ML algorithms learn from data. They identify patterns and relationships within the data and use this knowledge to make predictions or decisions.
#     *   **Supervised Learning:** The AI is trained on labeled data. It learns to map inputs to desired outputs. Think of the cat example – input is an image, output is "cat."
#     *   **Unsupervised Learning:** The AI is given unlabeled data and tries to find hidden patterns, structures, or clusters on its own. This is useful for tasks like customer segmentation or anomaly detection.
#     *   **Reinforcement Learning:** The AI learns by trial and error, through rewards and punishments. It's like teaching a dog tricks – when it does something right, it gets a treat (reward); when it does something wrong, it gets a gentle correction (punishment). This is often used in robotics and game playing.
# *   **Deep Learning (DL):** A subfield of ML that uses artificial neural networks with multiple layers (hence "deep"). These networks are inspired by the structure of the human brain. Each layer processes information and passes it on to the next, allowing the AI to learn increasingly complex representations of data.
#     *   **Neural Networks:** These are interconnected nodes (like neurons) that process and transmit information.
#     *   **Layers:** Different layers in a neural network specialize in recognizing different features, from simple edges and colors in an image to more complex shapes and objects.
#
# **3. How the Learning Happens (Simplified)**
#
# Imagine you're teaching a child to identify apples.
#
# *   **You show them an apple:** "This is an apple." (Labeled data)
# *   **They see its properties:** Red, round, has a stem.
# *   **They start noticing patterns:** Other round, red fruits might also be apples, but maybe some are too soft or too big.
# *   **They make a guess:** "Is this an apple?"
# *   **You correct them:** "No, that's a tomato." (Feedback and correction)
# *   **They adjust their understanding:** "Okay, so not *all* round red things are apples. Apples are also usually firm."
#
# AI learning is a highly sophisticated version of this. Algorithms adjust their internal parameters (weights and biases in neural networks) based on the data and feedback to minimize errors and improve accuracy.
#
# **4. Key Components and Processes:**
#
# *   **Feature Extraction:** Identifying the relevant characteristics of the data that are important for the task.
# *   **Model Training:** The process of feeding data to the algorithm and adjusting its parameters to learn.
# *   **Prediction/Inference:** Once trained, the AI can use its learned knowledge to make predictions on new, unseen data.
# *   **Evaluation:** Measuring how well the AI performs using various metrics.
#
# **5. Types of AI:**
#
# *   **Narrow AI (or Weak AI):** This is what we have today. AI designed and trained for a specific task, like voice assistants (Siri, Alexa), image recognition software, or recommendation engines.
# *   **General AI (or Strong AI):** This is hypothetical AI that would possess human-level intelligence across a wide range of tasks, capable of understanding, learning, and applying knowledge in any domain. We are not there yet.
# *   **Super AI:** Hypothetical AI that would surpass human intelligence in all aspects.
#
# **In a Nutshell:**
#
# AI works by using **algorithms** that can **learn from data**. Instead of being explicitly programmed for every situation, these algorithms identify patterns, make predictions, and improve their performance over time through training and feedback. **Machine learning**, particularly **deep learning** with its **neural networks**, is the dominant force behind modern AI, enabling it to tackle increasingly complex and sophisticated tasks.
#
# It's important to remember that AI isn't magic. It's a result of advanced mathematics, computer science, and the availability of vast amounts of data.

# %%
# Out:
# At its core, Artificial Intelligence (AI) isn't magic, and it isn't a conscious mind. It is **highly advanced mathematics and statistics** powered by massive computer processing.
#
# To understand how AI works, it helps to contrast it with traditional computer programming.
#
# *   **Traditional Programming:** You give the computer **data** + **rules** (instructions) = You get an **answer**. (e.g., "If the number of legs is 4 and it barks, label it a dog.")
# *   **Artificial Intelligence:** You give the computer **data** + **answers** = The computer figures out the **rules**. (e.g., You show it 10,000 photos of dogs, and it figures out what makes a dog a dog.)
#
# Here is a step-by-step breakdown of how modern AI works.
#
# ---
#
# ### 1. The Fuel: Data
# AI cannot learn without data. This data can be text (like the entire internet), images, audio, or numbers (like stock market trends).
# *   If you want to build an AI that detects skin cancer, you must first feed it millions of images of healthy skin and cancerous moles.
#
# ### 2. The Engine: Machine Learning (ML)
# Machine Learning is the most common type of AI today. Instead of writing code to cover every possible scenario, we write an **algorithm** (a mathematical recipe) that allows the computer to learn from the data.
#
# Inside Machine Learning is a subfield called **Deep Learning**, which mimics the human brain. It uses **Artificial Neural Networks**:
# *   Imagine millions of tiny, interconnected virtual "light switches" called neurons.
# *   These neurons are arranged in layers.
# *   When you feed an image of a cat into the network, the first layer might detect simple lines and edges. The next layer detects shapes (circles, triangles). The next layer detects features (whiskers, ears). The final layer outputs the guess: "Cat."
#
# ### 3. The Process: Training and Feedback
# When an AI is first built, it knows nothing. If you show it a picture of a cat, it might guess "banana."
#
# To make it smart, we **train** it through a trial-and-error process:
# 1.  **The Guess:** The AI makes a prediction.
# 2.  **The Correction:** The system compares the guess to the correct answer (provided by humans).
# 3.  **The Adjustment (Backpropagation):** If the AI was wrong, a mathematical formula adjusts the connections (the "knobs" or "weights") between the virtual neurons.
# 4.  **Repeat:** This is done millions or billions of times until the AI’s guesses are highly accurate.
#
# ### 4. The Output: Inference
# Once the AI is trained, its "knobs" are locked in place. You can now give it brand-new data that it has never seen before, and it will make an accurate prediction. This stage is called **inference**.
#
# For example, when you upload a photo to Google Photos and it automatically groups your dog’s pictures together, that is the AI running inference.
#
# ---
#
# ### How "Generative AI" (like ChatGPT or Midjourney) Works
# You’ve likely interacted with Generative AI. These models don't just classify data; they create new things.
# *   **ChatGPT (Large Language Models):** ChatGPT doesn't "know" facts like a human does. Instead, it is a **super-advanced autocomplete**. Because it has read billions of pages of text, it knows which word is mathematically most likely to come next in a sentence based on your prompt.
# *   **Midjourney/DALL-E (Image Generators):** They use a process called "diffusion." They start with a field of random static (like television snow) and gradually clean up the static step-by-step until it forms the image you asked for, based on patterns it learned during training.
#
# ---
#
# ### Why is AI Booming Now?
# AI concepts were invented in the 1950s, but they are only taking over now because of two things:
# 1.  **The Internet:** We finally have enough data (images, text, videos) to train these systems.
# 2.  **GPUs (Graphics Processing Units):** These computer chips, originally designed for 3D video games, happen to be perfect for running the massive, parallel mathematical equations that AI requires.
#
# ### Summary
# AI works by **finding patterns in data**. It takes massive amounts of information, uses mathematical algorithms to learn the underlying patterns, and then uses those patterns to make predictions, decisions, or generate entirely new content.

# %%
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 response = client.chat.completions.create(
#       2     model="gemini-3.5-flash",
#       3     messages=[
#       4         {   "role": "system",
#
# File /workspaces/LLM-Project/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File /workspaces/LLM-Project/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File /workspaces/LLM-Project/.venv/lib/python3.12/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /workspaces/LLM-Project/.venv/lib/python3.12/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# InternalServerError: Error code: 503 - [{'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}]
